# %% [markdown]
# # Exercises

# %%
# 1.Use matplotlib to plot the following equation:
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#y=x**2−x+2
#
#You'll need to write the code that generates the x and y points.
#
#Add an anotation for the point 0, 0, the origin.

# %%
x = list(range(15))
# must change x in equation to another variable 'n' and do 'for n in x' to pull from the x[list]
# y = [n ** 2 for n in x]
y = [n**2 - n+2 for n in x] 

plt.plot(x,y)

plt.annotate('The Origin', xy=(0,0),xytext=(4,125),
             arrowprops={'facecolor': 'blue'})
plt.show()

# %%
# 2.Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#   
#   y=√x
#   y=x3
#   y=2x
#   y=1/(x+1)
#   You can use functions from the math module to help implement some of the equations above.

# %%
x = list(range(10))

y = [np.sqrt(n) for n in x] 
plt.plot(x,y)
plt.title('y=√x')
plt.xlabel('$x$')
plt.ylabel('$x^2$')
plt.show()

# %%
x = list(range(10))
y = [n**3 for n in x]
plt.plot(x,y)
plt.title('y=x^3')
plt.xlabel('$x$')
plt.ylabel('$x^3$')
plt.show()

# %%
x = list(range(10))
y = [2**n for n in x]
plt.plot(x,y)
plt.title(' y=2x')
plt.xlabel('$x$')
plt.ylabel('$2x$')
plt.show()

# %%
x = list(range(10))
y = [1/(n+1) for n in x]
plt.plot(x,y)
plt.title(' y=1/(x+1)')
plt.xlabel('$x$')
plt.ylabel('$1/(x+1)$')
plt.show()

# %%
# 3. Combine the figures you created in the last step into one large figure with 4 subplots.

x = np.linspace(-5,6)
plt.figure(figsize=(12,8))

plt.subplot(221)
y = [np.sqrt(n) for n in x] 
plt.title('y=√x')
plt.xlabel('$x$')
plt.ylabel('$x^2$')
plt.plot(x,y)


plt.subplot(222)
y = [n**3 for n in x]
plt.title('y=x^3')
plt.xlabel('$x$')
plt.ylabel('$x^3$')
plt.plot(x,y)


plt.subplot(223)
y = [2**n for n in x]
plt.plot(x,y)
plt.title(' y=2x')
plt.xlabel('$x$')
plt.ylabel('$2x$')


plt.subplot(224)
y = [1/(n+1) for n in x]
plt.title('y=1/(x+1)')
plt.xlabel('$x$')
plt.ylabel('$1/(x+1)$')
plt.plot(x,y)
plt.ylim(-10,10)
plt. xlim(-10,10)

plt.show()
# Out:
# /var/folders/2s/5h_f818x4h11v8k6kc_6g1700000gn/T/ipykernel_30144/2882703974.py:7: RuntimeWarning: invalid value encountered in sqrt
#   y = [np.sqrt(n) for n in x]

# %%
# 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different 
#    color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
x = np.linspace(-10,10)

plt.plot(x1, c='green', alpha=1,label='$y=√x$')
plt.plot(x2, c='red', alpha=1,label='$y=x^3$')
plt.plot(x3, c='blue', alpha=1,label='$y=2x$')
plt.plot(x4, c='purple', alpha=1,label='$1/(x+1)$')
plt.xlabel('$x$')
plt.ylabel('$y$')

y = [np.sqrt(n) for n in x] 
plt.plot(x,y)

y2 = [n**3 for n in x]
plt.plot(x,y2)

y3 = [2**n for n in x]
plt.plot(x,y3)

y4 = [1 / (n+1) for n in x]
plt.plot(x,y4)

plt.ylim(-2,10)
plt. xlim(-2,10)

plt.legend(loc='upper center')
plt.title('Comparison of 4 lines')
plt.xlabel('$x$')

plt.show()
# Out:
# /var/folders/2s/5h_f818x4h11v8k6kc_6g1700000gn/T/ipykernel_30144/3583445894.py:10: RuntimeWarning: invalid value encountered in sqrt
#   y = [np.sqrt(n) for n in x]

# %%
# 5.
